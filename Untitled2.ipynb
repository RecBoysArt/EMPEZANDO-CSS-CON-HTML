# %% [markdown]
# <a href="https://colab.research.google.com/github/RecBoysArt/EMPEZANDO-CSS-CON-HTML/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Programa para verificar si sos mayor o menor de edad

# Pedimos la edad al usuario
edad = int(input("Ingresá tu edad: "))

# Verificamos si es mayor o menor de edad
if edad >= 18:
    print("Sos mayor de edad.")
else:
    print("Sos menor de edad.")
# Out:
# Ingresá tu edad: 12
# Sos menor de edad.
